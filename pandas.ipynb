# %% [markdown]
# This Python notebook is created to study the fundamental functionalities and methods of pandas library by applying them to a real-world dataset.
#
# Pandas is a powerful open-source data manipulation and analysis library in Python. It provides easy-to-use data structures like DataFrames that allow efficient handling and analysis of structured data. This notebook serves as a learning resource to explore and understand the key features and techniques offered by pandas.
#
# Let's dive into the world of pandas and leverage its capabilities to gain a deeper understanding of data manipulation and analysis in Python!

# %% [markdown]
# This code imports the "pandas" and "matplotlib.pyplot" libraries.
#
# The line `import pandas as pd` imports the "pandas" library and assigns it an alias "pd". This allows you to use the alias "pd" to access the features of the "pandas" library throughout the code.
#
# The line `import matplotlib.pyplot as plt` imports the "pyplot" module from the "matplotlib" library and assigns it an alias "plt". This allows you to use the alias "plt" to access the functions and features of the "pyplot" module throughout the code.
#
# These libraries are commonly used for data analysis and graphical visualization. "Pandas" is used for data manipulation and analysis, while "matplotlib.pyplot" is used for creating plots and visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The following code reads and print the beginning of a CSV file named "athlete_events.csv" using the pandas library.
#
# The function `pd.read_csv()` is called to read the CSV file. The file path 'dataset/athlete_events.csv' specifies the location of the file on the system. The resulting data is then stored in the variable named "dataset".

# %%
dataset = pd.read_csv('dataset/athlete_events.csv')
dataset.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# The code `dataset.shape` retrieves the shape of a dataset. It will return a tuple containing the dimensions of the dataset. The first element of the tuple represents the number of rows in the dataset, and the second element represents the number of columns.

# %%
dataset.shape
# Out:
# (271116, 15)

# %% [markdown]
# The code `dataset.describe()` generates descriptive statistics of a dataset. It will compute various summary statistics of the numerical columns in the dataset. The output will include count, mean, standard deviation, minimum value, 25th percentile, median (50th percentile), 75th percentile, and maximum value for each numerical column.
#
# This method provides valuable insights into the distribution and central tendencies of the data, helping to understand the range, dispersion, and potential outliers present in the dataset. It is particularly useful for initial exploratory data analysis and understanding the basic statistical characteristics of the data.

# %%
dataset.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# The code `dataset.loc[dataset['Age'] > 35]` filters the dataset based on a condition, specifically where the 'Age' column is greater than 35.
#
# This code retrieves rows from the dataset where the age is greater than 35. The `loc` function is used to access specific rows and columns based on a given condition. In this case, it selects all rows where the value in the 'Age' column is greater than 35.
#
# The resulting output will be a new DataFrame that contains only the rows where the age is greater than 35, preserving the original structure and columns of the dataset.

# %%
dataset.loc[dataset['Age'] > 35]
# Out:
#             ID                   Name Sex   Age  Height  Weight     Team  NOC  \
# 58          19  Win Valdemar Aaltonen   M  54.0     NaN     NaN  Finland  FIN
# 89          28       Jan-Erik Aarberg   M  43.0   170.0    77.0   Norway  NOR
# 90          28       Jan-Erik Aarberg   M  47.0   170.0    77.0   Norway  NOR
# 124         45            Hakon Aasns   M  41.0     NaN     NaN   Norway  NOR
# 126         46             Hans Aasns   M  45.0   194.0    93.0   Norway  NOR
# ...        ...                    ...  ..   ...     ...     ...      ...  ...
# 271083  135554           Bogusaw Zych   M  36.0   182.0    82.0   Poland  POL
# 271084  135554           Bogusaw Zych   M  36.0   182.0    82.0   Poland  POL
# 271085  135554           Bogusaw Zych   M  36.0   182.0    82.0   Poland  POL
# 271090  135557           Dominik ycki   M  38.0   192.0    95.0   Poland  POL
# 271099  135560      Stavroula Zygouri   F  36.0   171.0    63.0   Greece  GRE
#
# ...

# %% [markdown]
# The code `dataset.rename(columns={'ID': 'Identifier'})` renames a column in the dataset from 'ID' to 'Identifier'. It will rename the column 'ID' to 'Identifier' in the dataset. This operation does not modify the original dataset directly but returns a new DataFrame with the updated column name.
#
# The resulting DataFrame will have the same data as the original dataset, but with the column name 'ID' replaced by 'Identifier'. This is useful when you want to change the column name to make it more descriptive or aligned with your data analysis needs.

# %%
dataset.rename(columns={'ID' : 'Identifier'})
# Out:
#         Identifier                      Name Sex   Age  Height  Weight  \
# 0                1                 A Dijiang   M  24.0   180.0    80.0
# 1                2                  A Lamusi   M  23.0   170.0    60.0
# 2                3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3                4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4                5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...            ...                       ...  ..   ...     ...     ...
# 271111      135569                Andrzej ya   M  29.0   179.0    89.0
# 271112      135570                  Piotr ya   M  27.0   176.0    59.0
# 271113      135570                  Piotr ya   M  27.0   176.0    59.0
# 271114      135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115      135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %% [markdown]
# The code `dataset['Sex'].value_counts()` calculates the count of unique values in the 'Sex' column of the pandas DataFrame named `dataset`.
#
# Calling `dataset['Sex'].value_counts()` will return a pandas Series object that displays the count of each unique value in the 'Sex' column. The unique values in the 'Sex' column will be the index of the Series, and the corresponding counts will be the values.
#
# This method is commonly used to analyze categorical data and understand the distribution of values within a specific column. In this case, it provides information about the frequency of each category in the 'Sex' column of the dataset.

# %%
dataset['Sex'].value_counts()
# Out:
# Sex
# M    196594
# F     74522
# Name: count, dtype: int64

# %% [markdown]
# The code `dataset.drop('NOC', axis=1)` removes the 'NOC' column from the pandas DataFrame `dataset`.
#
# Calling `dataset.drop('NOC', axis=1)` will return a new DataFrame with the 'NOC' column removed. The `drop()` function is used to eliminate columns or rows from a DataFrame, and in this case, we specify 'NOC' as the column to be dropped.
#
# The resulting DataFrame will be the same as the original `dataset`, but without the 'NOC' column. The 'axis=1' parameter specifies that we are referring to a column, as opposed to 'axis=0', which would refer to a row.

# %%
dataset.drop('NOC', axis=1)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team        Games  Year  Season            City  \
# 0                China  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# The code `dataset.hist(column='Age', bins=100)` generates a histogram for the 'Age' column of the pandas DataFrame `dataset`.
#
# Calling `dataset.hist(column='Age', bins=100)` will plot a histogram of the values in the 'Age' column. The 'column' parameter specifies the column to be plotted, which is 'Age' in this case. The 'bins' parameter determines the number of bins or intervals to be used in the histogram. In this example, the histogram will be divided into 100 bins.
#
# The resulting histogram will provide a visual representation of the distribution of ages in the dataset. It can help identify patterns, outliers, and the overall shape of the age distribution.

# %%
dataset.hist(column='Age', bins=100)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %% [markdown]
# The code `dataset.boxplot(column=['Age', 'Weight', 'Height'])` generates a box plot for the 'Age', 'Weight', and 'Height' columns of the pandas DataFrame `dataset`.
#
# Calling `dataset.boxplot(column=['Age', 'Weight', 'Height'])` will create a box plot for each of the specified columns. The 'column' parameter takes a list of column names ['Age', 'Weight', 'Height'] in this case.
#
# A box plot provides a visual summary of the distribution of numerical data, displaying the minimum, first quartile (25th percentile), median (second quartile or 50th percentile), third quartile (75th percentile), and maximum values. It also shows any potential outliers in the data.
#
# The resulting box plot will allow you to compare the distributions and identify any variations or outliers in the 'Age', 'Weight', and 'Height' columns of the dataset.

# %%
dataset.boxplot(column=['Age', 'Weight', 'Height'])
# Out:
# <Axes: >

# %% [markdown]
# The following code creates a scatter plot using the 'Height' and 'Weight' columns from the pandas DataFrame `dataset` using the matplotlib library.
#
# The code first assigns the 'Height' column to the variable `x` and the 'Weight' column to the variable `y` from the `dataset` DataFrame.
#
# Then, `plt.scatter(x, y)` is used to create a scatter plot, where the 'Height' values are plotted along the x-axis and the 'Weight' values are plotted along the y-axis.
#
# Finally, `plt.plot()` is called to display the scatter plot.
#
# This code allows you to visualize the relationship between 'Height' and 'Weight' variables for the dataset, providing insights into any potential correlations or patterns between these two variables.

# %%
x = dataset['Height']
y = dataset['Weight']
plt.scatter(x, y)
plt.plot()
# Out:
# []

# %% [markdown]
# The code `completeData = dataset.dropna()` creates a new DataFrame named `completeData` by removing rows with missing values from the original pandas DataFrame `dataset`.
#
# Calling `dataset.dropna()` drops any rows from the `dataset` DataFrame that contain one or more missing values (NaN). The resulting DataFrame, assigned to `completeData`, will only include rows without any missing values.
#
# By using `completeData`, you now have a DataFrame that only contains complete (non-missing) data, which can be useful for analysis or modeling purposes.

# %%
completeData = dataset.dropna()
completeData.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
# 48  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# ...

# %% [markdown]
# The code `isnull = dataset.isnull()` creates a new DataFrame named `isnull` that indicates the presence of missing values (NaN) in the original pandas DataFrame `dataset`.
#
# Calling `dataset.isnull()` returns a DataFrame of the same shape as `dataset`, where each cell contains a boolean value indicating whether the corresponding cell in `dataset` is null or not. If a cell contains a missing value, the corresponding cell in `isnull` will be True; otherwise, it will be False.
#
# By assigning the result to `isnull`, you create a new DataFrame that can be used to check for the presence of missing values across the columns of `dataset`.
#
# This can be helpful for identifying the locations and patterns of missing data in your dataset, allowing you to handle or address them appropriately in your analysis or data processing tasks.

# %%
isnull = dataset.isnull()
isnull.head()
# Out:
#       ID   Name    Sex    Age  Height  Weight   Team    NOC  Games   Year  \
# 0  False  False  False  False   False   False  False  False  False  False
# 1  False  False  False  False   False   False  False  False  False  False
# 2  False  False  False  False    True    True  False  False  False  False
# 3  False  False  False  False    True    True  False  False  False  False
# 4  False  False  False  False   False   False  False  False  False  False
#
#    Season   City  Sport  Event  Medal
# 0   False  False  False  False   True
# 1   False  False  False  False   True
# 2   False  False  False  False   True
# 3   False  False  False  False  False
# 4   False  False  False  False   True

# %% [markdown]
# The code `missingData = dataset.isnull().sum()` creates a pandas Series named `missingData` that calculates the count of missing values in each column of the original pandas DataFrame `dataset`.
#
# Calling `dataset.isnull().sum()` first checks for missing values in each cell of the `dataset` DataFrame using `isnull()`, resulting in a DataFrame of the same shape with boolean values indicating the presence of missing values. Then, `sum()` is applied to calculate the sum of missing values for each column.
#
# The resulting `missingData` Series contains the column names of `dataset` as the index and the corresponding counts of missing values as the values. This information can be used to identify columns with missing data and assess the extent of missingness in each column.
#
# Analyzing the `missingData` Series can help in making decisions regarding how to handle or impute missing values in the dataset before performing further analysis or modeling.

# %%
missingData = dataset.isnull().sum()
print(missingData)
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# The code `missingPercent = (missingData / len(dataset['ID'])) * 100` calculates the percentage of missing values in each column of the original pandas DataFrame `dataset` and stores it in the `missingPercent` variable.
#
# Here, `missingData` is assumed to be a pandas Series that contains the count of missing values in each column of `dataset`. `len(dataset['ID'])` retrieves the number of rows in the 'ID' column (assuming it has no missing values).
#
# By dividing each count of missing values by the total number of rows and multiplying by 100, we obtain the percentage of missing values for each column. The resulting values are stored in the `missingPercent` Series.
#
# This can be useful for assessing the extent of missing data in each column as a percentage. It provides a quantitative measure of the completeness of the dataset and helps prioritize columns for further investigation or imputation if necessary.

# %%
missingPercent = (missingData / len(dataset['ID'])) * 100
print(missingPercent)
# Out:
# ID         0.000000
# Name       0.000000
# Sex        0.000000
# Age        3.494445
# Height    22.193821
# Weight    23.191180
# Team       0.000000
# NOC        0.000000
# Games      0.000000
# Year       0.000000
# Season     0.000000
# City       0.000000
# Sport      0.000000
# Event      0.000000
# Medal     85.326207
# dtype: float64

# %% [markdown]
# The code `dataset['Medal'].fillna('None', inplace=True)` fills the missing values in the 'Medal' column of the pandas DataFrame `dataset` with the value 'None'.
#
# The `fillna()` function is called on the 'Medal' column of the DataFrame, specifying the value 'None' as the replacement for missing values. The `inplace=True` parameter ensures that the changes are made directly to the original DataFrame `dataset`, modifying it in place.
#
# This operation replaces any missing values in the 'Medal' column with the string 'None'. This is a common approach when dealing with missing values in categorical variables, where 'None' is used to indicate the absence of a medal in this case.
#
# After executing this code, the 'Medal' column in `dataset` will have missing values filled with 'None', ensuring that all rows have a value in that column.

# %%
dataset['Medal'].fillna('None', inplace=True)
dataset.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball  None
# 1      Judo Men's Extra-Lightweight  None
# ...
